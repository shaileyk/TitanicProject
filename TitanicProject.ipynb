# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df = pd.read_csv("train.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import IPython
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.catplot('Sex',data=titanic_df, kind="count")

# %%
sns.catplot('Sex',data=titanic_df, kind="count", hue='Pclass')

# %%
sns.catplot('Pclass',kind="count", data=titanic_df, hue='Sex')

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age<16:
        return 'child'
    else:
        return sex

# %%
titanic_df['Person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.catplot('Pclass',data=titanic_df,kind="count",hue='Person')

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['Person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: Person, dtype: int64

# %%
titanic_df.groupby(['Person','Pclass']).size() #gender and class
# Out:
# Person  Pclass
# child   1           6
#         2          19
#         3          58
# female  1          91
#         2          66
#         3         114
# male    1         119
#         2          99
#         3         319
# dtype: int64

# %%
titanic_df.groupby(['Person','Pclass','Survived']).size() #what kind of people survived
# Out:
# Person  Pclass  Survived
# child   1       0             1
#                 1             5
#         2       1            19
#         3       0            33
#                 1            25
# female  1       0             2
#                 1            89
#         2       0             6
#                 1            60
#         3       0            58
#                 1            56
# male    1       0            77
#                 1            42
#         2       0            91
#                 1             8
#         3       0           281
#                 1            38
# dtype: int64

# %%
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

# %%
oldest = titanic_df['Age'].max()

# %%
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='Person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []

# %%
for level in deck:
    levels.append(level[0])
    
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']
sns.catplot('Cabin',data = cabin_df,kind="count",palette="winter_d")

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.catplot('Cabin',data = cabin_df,kind="count",palette="summer")

# %%
sns.catplot('Embarked',data=titanic_df, kind="count", hue="Pclass", row_order = ['C','Q','S'])

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Alone'] = titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone']>0] = "with family"
titanic_df['Alone'].loc[titanic_df['Alone'] == 0] = "Alone"

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.catplot('Alone',kind="count",data=titanic_df,palette="Blues")

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0:"no",1:"yes"})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.catplot('Survivor', data=titanic_df, palette="Set1", kind="count")

# %%
sns.catplot('Pclass',"Survived",data=titanic_df,kind="bar", hue="Person", palette="Set1")

# %%
sns.lmplot("Age","Survived",data=titanic_df)

# %%
sns.lmplot("Age","Survived",data=titanic_df, hue="Pclass", palette="summer")

# %%
generations = [10,20,30,40,50,60,70,80]
sns.lmplot("Age","Survived",data=titanic_df, hue="Pclass", palette="summer", x_bins=generations)

# %%
sns.lmplot("Age","Survived",data=titanic_df, hue="Sex", palette="summer")

# %%
#Did the deck had an affect in the survival rate
#Did having the family member helped in surviving

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
cabin_df.Cabin
# Out:
# 0      C
# 1      C
# 2      E
# 3      G
# 4      C
# 5      D
# 6      A
# 7      C
# 8      B
# 9      D
# 10     B
# 11     C
# 12     B
# 13     C
# 14     F
# 15     F
# 16     C
# 17     E
# 18     A
# 19     D
# 20     D
# 21     C
# 22     B
# 23     E
# 24     D
# 25     F
# 26     D
# 27     C
# 28     B
# 29     F
#       ..
# 378    E
# 379    B
# 380    B
# 381    D
# 382    E
# 383    F
# 384    B
# 385    B
# 386    D
# 387    B
# 388    D
# 389    B
# 390    A
# 391    E
# 392    B
# 393    B
# 394    E
# 395    B
# 396    E
# 397    C
# 398    C
# 399    D
# 400    E
# 401    D
# 402    A
# 403    D
# 404    B
# 405    C
# 406    B
# 407    C
# Name: Cabin, Length: 406, dtype: object

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Person  \
# 886    male  27.0      0      0      211536  13.00   NaN        S    male
# 887  female  19.0      0      0      112053  30.00   B42        S  female
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  female
# 889    male  26.0      0      0      111369  30.00  C148        C    male
# 890    male  32.0      0      0      370376   7.75   NaN        Q    male
#
#            Alone Survivor Deck
# ...

# %%
cabin_df.head()
# Out:
#   Cabin
# 0     C
# 1     C
# 2     E
# 3     G
# 4     C

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.loc[titanic_df['Cabin'].notnull(), 'Deck'] = titanic_df['Cabin'].str[0]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Person  \
# 886    male  27.0      0      0      211536  13.00   NaN        S    male
# 887  female  19.0      0      0      112053  30.00   B42        S  female
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  female
# 889    male  26.0      0      0      111369  30.00  C148        C    male
# 890    male  32.0      0      0      370376   7.75   NaN        Q    male
#
#            Alone Survivor Deck
# ...

# %%
titanic_df["Deck"].fillna(0)
# Out:
# 0      0
# 1      C
# 2      0
# 3      C
# 4      0
# 5      0
# 6      E
# 7      0
# 8      0
# 9      0
# 10     G
# 11     C
# 12     0
# 13     0
# 14     0
# 15     0
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     D
# 22     0
# 23     A
# 24     0
# 25     0
# 26     0
# 27     C
# 28     0
# 29     0
#       ..
# 861    0
# 862    D
# 863    0
# 864    0
# 865    0
# 866    0
# 867    A
# 868    0
# 869    0
# 870    0
# 871    D
# 872    B
# 873    0
# 874    0
# 875    0
# 876    0
# 877    0
# 878    0
# 879    C
# 880    0
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    B
# 888    0
# 889    C
# 890    0
# Name: Deck, Length: 891, dtype: object

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df["Deck"] = titanic_df["Deck"].fillna(0)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df["Deck"] = titanic_df["Deck"].replace({5:'Z'})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df["Deck_inNumbers"] = [ ord(x) for x in titanic_df.Deck ]

# %%
titanic_df.Deck[titanic_df.Deck=='Z'] =0
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.Deck[titanic_df.Deck=='A'] =1
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='B']=2
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='C']=3
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.Deck[titanic_df.Deck=='D']=4
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='E']=5
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='F']=6
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='G']=7
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='H']=8
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='I']=9
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Deck[titanic_df.Deck=='T']=10
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cabin_df.head
# Out:
# <bound method DataFrame.head of     Cabin
# 0       C
# 1       C
# 2       E
# 3       G
# 4       C
# 5       D
# 6       A
# 7       C
# 8       B
# 9       D
# 10      B
# 11      C
# 12      B
# 13      C
# 14      F
# 15      F
# 16      C
# 17      E
# 18      A
# 19      D
# 20      D
# 21      C
# 22      B
# 23      E
# 24      D
# 25      F
# 26      D
# 27      C
# 28      B
# 29      F
# ..    ...
# 378     E
# 379     B
# 380     B
# 381     D
# 382     E
# 383     F
# 384     B
# 385     B
# 386     D
# 387     B
# 388     D
# 389     B
# 390     A
# 391     E
# 392     B
# 393     B
# 394     E
# 395     B
# 396     E
# 397     C
# 398     C
# 399     D
# 400     E
# 401     D
# 402     A
# 403     D
# 404     B
# 405     C
# 406     B
# 407     C
#
# [406 rows x 1 columns]>

# %%
titanic_df.loc[titanic_df['Cabin'].notnull(), 'Deck'] = titanic_df['Cabin'].str[0]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df["Deck"] = titanic_df["Deck"].replace({0:'Z'})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df["Deck_inNumbers"] = [ ord(x)-64 for x in titanic_df["Deck"] ]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.lmplot("Pclass","Survived",data=titanic_df,hue="Sex")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  with family
# 1      0          PC 17599  71.2833   C85        C  female  with family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
titanic_df.Alone[titanic_df.Alone=="with family"] = "WithFamily"
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person       Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  WithFamily
# 1      0          PC 17599  71.2833   C85        C  female  WithFamily
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female       Alone
# ...

# %%
titanic_df.Alone[titanic_df.Alone == "Alone"] = 0
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.Alone[titanic_df.Alone == "WithFamily"]=1
# Out:
# C:\Users\Shailey Kadam\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic_df.groupby(["Pclass","Person","Survived"]).size()
# Out:
# Pclass  Person  Survived
# 1       child   0             1
#                 1             5
#         female  0             2
#                 1            89
#         male    0            77
#                 1            42
# 2       child   1            19
#         female  0             6
#                 1            60
#         male    0            91
#                 1             8
# 3       child   0            33
#                 1            25
#         female  0            58
#                 1            56
#         male    0           281
#                 1            38
# dtype: int64

# %%
titanic_df.groupby(["Person","Survived"]).size()
# Out:
# Person  Survived
# child   0            34
#         1            49
# female  0            66
#         1           205
# male    0           449
#         1            88
# dtype: int64
